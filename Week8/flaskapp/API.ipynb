# %% [raw]
# # What is mean by API? - heterogeneous system connection
# Database return by SQL
# Webpage designed by .Net
# Connecting b/w these two developer using python.
# So API provide lanauge independent, OS independent - so esaly connect & exchnage the information(Bridge b/w the different application)
# The use case may be with in company or external.
# or consume others info
# Example IRCTC- data feaching
# Another example:
# swiggy -Search the phone - Next query oder- Then order table -
# iNeuron -Course portal
# GPAY - BANK
# So we need to standardize or common structure
#
# First wsdl  -  web service description language - using  SOAP  proptocal - request & response based.( It's contract)
#
# Next - we will go for light wight api - So people use REST API then JSON Format.
#
# we can create the API from any language
#
# Python - web application Framework.
#          Dijango or flask or clean - lib- These are call Web application develpment Framework(WAPD)
#          we can develop API based on GUI or REST API( Give the URL)
# we need to estblish bridge b/w python to web portal ( Example: Jupyter Notebook) or POST Application.
# This is bidirectional communication.
#
# API is combination of URL ::PORT
# using flask - we will create API - This will help expose my mothed to outside.
#
# Example:
#
# Calculator - Core logic in Python - from web portal (HTML or Java) we can call those method & excute.
#
# Dijango is 4X fater than flask

# %% [markdown]
# - Example I have created function in python
#
# def Test():
#     return 1+2
# - I don't wan't execute from Pyhton, But I want to execute from external system.
# - Create the flask object & Bind with URL.
#
# So that will create the route.
# ![image.png](attachment:image.png)

# %% [markdown]
# - / always bind home route.
# - if we have another method we can give the method Name
# - I can create N route & attach the spefic method.
# - Suppouse the function/Method is avaliable/hosted in server.
# - We have hit the function/method using the server address & port.
# - Even we can pass the data.
# - we can pass the  data in two ways - POST & GET.
#
# Example:
#
# Google - Type data Science - From the URL & every body can see the my Query.  - This is called GET
#
# GET == No secure ways - Just add my query with URL
#
# Suppouse - I am login using user & password in Gmail - Whether my user Name /Pass is avaliable in my URL or query? No
# - Both case I am sending data to server. - This is called POST
#
# We are sending as BODY - Secure way.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## When to creat API ?
# https://programminghistorian.org/en/lessons/creating-apis-with-python-and-flask

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# C:\ProgramData\Anaconda3\python.exe
# 3.6.8 |Anaconda, Inc.| (default, Feb 11 2019, 15:03:47) [MSC v.1915 64 bit (AMD64)]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)

# %% [raw]
# What will do more than 20 GB data in ML Mode?
# Query means - index based - MongoBD
# If it's column based = SQL or HBASE
# Predict & Load = AWS S3 or AZUSURE

# %% [markdown]
# ML Pipeline :

# %% [markdown]
# https://openweathermap.org/api

# %% [markdown]
# https://singularitynet.io/
