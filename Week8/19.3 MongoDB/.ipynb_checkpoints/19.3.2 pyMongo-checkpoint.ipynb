# %% [markdown]
# <img src="https://d24cdstip7q8pz.cloudfront.net/t/ineuron1/content/common/images/final%20logo.png" height=60 alt-text="iNeuron.ai logo">

# %% [markdown]
# ### JSON format & difference b/w SQL vs mongo DB
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 19.3.2 Open MongoDB compass to visually see what each python commands does
#
# You'll see below screen -
#
# > ![first screen](mongo_img/compass/c1.JPG)

# %% [markdown]
# ### STEP 1: Create a DB

# %%
import pymongo

# %%
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = "iNeuron"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]
dataBase
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'iNeuron')

# %% [markdown]
# ---
#
# ### Paste the default URL in highlighted area of the Compass tool as shown below and click on connect
# default URL for local system:-
# ```
# mongodb://localhost:27017/
# ```
#
# > ![new connection](mongo_img/compass/c2.JPG)
#
#  if you are not able to connect - go to windows  - Restart the mangodb service manually
#
# > ![image.png](attachment:image.png)
#
# after you press connect you'll see the following screen which contains already existing databases
#
# > ![new connection](mongo_img/compass/c3.JPG)
#
#
# <b> **NOTE** you'll not see your database untill or unless you have created first document inside it. So at present we don't have any document in our DB its name is not visible here <b>
#
# You can also create a database by clicking on CREATE DATABSE button. You'll see a below screen (But we'll see eveyrthing using python)
#
# > ![new connection](mongo_img/compass/c4.JPG)

# %%
# lets see what the existing list of DBs -

client.list_database_names()
# Out:
# ['admin', 'config', 'iNeuron', 'local']

# %% [markdown]
# <b> **NOTE** you'll not see your database untill or unless you have created first document inside it. So at present we don't have any document in our DB its name is not visible here <b>

# %%
# let's verify whether we have our database in the list or not 
# Db name we have already defined in the above cell
# we'll use the following function:-

def checkExistence_DB(DB_NAME, client):
    """It verifies the existence of DB"""
    DBlist = client.list_database_names()
    if DB_NAME in DBlist:
        print(f"DB: '{DB_NAME}' exists")
        return True
    print(f"DB: '{DB_NAME}' not yet present OR no collection is present in the DB")
    return False


_ = checkExistence_DB(DB_NAME=DB_NAME, client=client)
# Out:
# DB: 'iNeuron' exists

# %% [markdown]
# ### STEP 2: Create a collection

# %%
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# %%
# let's verify whether we have our database in the list or not 
# we'll use the following function:-

def checkExistence_COL(COLLECTION_NAME, DB_NAME, db):
    """It verifies the existence of collection name in a database"""
    collection_list = db.list_collection_names()
    
    if COLLECTION_NAME in collection_list:
        print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' exists")
        return True
    
    print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' does not exists OR \n\
    no documents are present in the collection")
    return False


_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Products' in Database:'iNeuron' exists

# %% [markdown]
# ### STEP 3: Insert a record in the collection

# %%
# Create the single record & use insert_one command
record = {'companyName': 'iNeuron',
         'product': 'Affordable AI',
         'courseOffered': 'Deep Learning for Computer Vision',
         'comments':'from single record'}

collection.insert_one(record)

# %%
# _ is place holder
# Example
a,b,c = 10,20,30
print(a,b,c)
a,b,_ = 100,200,300
print(a,b,_)
# Out:
# 10 20 30
# 100 200 300

# %%
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Products' in Database:'iNeuron' exists

# %% [markdown]
# Now you can verify in Compass that iNeuron DB exists: -
#
# > ![verify Db](mongo_img/compass/c5.JPG)
# > **NOTE**: You may need to click refresh button if your DB is not visible here.
#
# You'll find collection name here-
# > ![verify Collection](mongo_img/compass/c6.JPG)
#
# Verify your inserted record with a unique id which is given by mongoDB by default -
# > ![check inserted document](mongo_img/compass/c7.JPG)
#
# Let's reverify whether our database and collection exists or not by using the function that we have defined before.

# %%
# Verify DATABASE
_ = checkExistence_DB(DB_NAME=DB_NAME, client=client)
# Out:
# DB: 'iNeuron' exists

# %%
# Verify COLLECTION
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Products' in Database:'iNeuron' exists

# %% [markdown]
# ### STEP 4: Insert multiple records

# %%
# Create the multiple record & use insert many option
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

rec = collection.insert_many(list_of_records)

# %%
# lets print he unique ID that of the record that we have inserted -
inserted_IDs = rec.inserted_ids

for idx, unique_ids in enumerate(inserted_IDs):
    print(f"{idx}. {unique_ids}")
# Out:
# 0. 6026bb2ab1f7dbd03d0f1f72
# 1. 6026bb2ab1f7dbd03d0f1f73
# 2. 6026bb2ab1f7dbd03d0f1f74

# %%
# Print all colletion indentifier.
agent_ids = collection.find().distinct('_id')
print(agent_ids)
# Out:
# [ObjectId('6026bb2ab1f7dbd03d0f1f71'), ObjectId('6026bb2ab1f7dbd03d0f1f72'), ObjectId('6026bb2ab1f7dbd03d0f1f73'), ObjectId('6026bb2ab1f7dbd03d0f1f74')]

# %%
# Getting id as string
agent_id2 = [str(id) for id in collection.find().distinct('_id')]
agent_id2
# Out:
# ['6026bb2ab1f7dbd03d0f1f71',
#  '6026bb2ab1f7dbd03d0f1f72',
#  '6026bb2ab1f7dbd03d0f1f73',
#  '6026bb2ab1f7dbd03d0f1f74']

# %% [markdown]
# We can verify the inserted records by refreshing our compass document-
#
# > ![inserted list of records](mongo_img/compass/c8.JPG)

# %% [markdown]
# You can override the default unique Id by giving a user defined as shown below -

# %%
#  Create the new collection and  give our own id
#  Select the new collection & observe the same in UI
#  if we re -execute error will diplay
# go to UI & delete each record manually & re execute.
COLLECTION_NAME = "iNeuron_Faculties"
faculties = dataBase[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "1",
    "companyName": "iNeuron",
    "Faculty": "Sudhanshu Kumar",
    'PhoneNumber':'001'},
    {"_id": "2",
    "companyName": "iNeuron",
    "Faculty": "Virat Sagar",
    'PhoneNumber':'002'},
    {"_id": "3",
    "companyName": "iNeuron",
    "Faculty": "Thangaraj",
    'PhoneNumber':'003'},
]

faculties_record = faculties.insert_many(list_of_records_user_defined_id)

# %% [markdown]
# refresh the Compass tool and you'll see a fresh collection is created by name iNeuron_Faculties
# and this time _id is defined by us. Refer the highlighted portion of the image below:-
#
# > ![unique_id](mongo_img/compass/c9.JPG)
#
# > **NOTE**: Make sure the \_id of the records that you insert are unique other wise you'll get a _BulkWriteError_ which comes because of duplicate key

# %% [markdown]
# ### STEP 5: Find method in MongoDB

# %%
# Get the first record from the faculties collection
find_first_record = faculties.find_one()

print(f"The first record of collection: \n{COLLECTION_NAME} is=\
\n{find_first_record}")
# Out:
# The first record of collection:
# iNeuron_Faculties is=
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# find all the record at once present in thr record with all the fields
all_record = faculties.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}
# 1: {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# 2: {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# find all the record at once present in the record with SPECIFIC fields
all_record = faculties.find({}, {"Faculty"})

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'Faculty': 'Sudhanshu Kumar'}
# 1: {'_id': '2', 'Faculty': 'Virat Sagar'}
# 2: {'_id': '3', 'Faculty': 'Thangaraj'}

# %%
# Suppose here we have 1 million reocord - we can use limit
all_record = faculties.find()[1]
all_record = faculties.find().limit(1)

# %%
# find all the record at once present in the record with mutiple mentioned fields
all_record = faculties.find({}, {"Faculty",'PhoneNumber',})

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}
# 1: {'_id': '2', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# 2: {'_id': '3', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %% [markdown]
# ### STEP 6: Query or filter out data in MongoDB

# %%
# Query based on id
query1 = {"_id": '1'}

results = faculties.find(query1)
for data in results:
    print(data)
# Out:
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# Query based on phone number
query1 = {'PhoneNumber': '003'}

results = faculties.find(query1)
for data in results:
    print(data)
# Out:
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# List all the record greate than one
query2 = {"_id": {"$gt": "1"}}

results = faculties.find(query2)
for data in results:
    print(data)
# Out:
# {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# Print less than 2
query2 = {"_id": {"$lt": "2"}}

results = faculties.find(query2)
for data in results:
    print(data)
# Out:
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# Print the Faculty start with T using regular expression
myquery = { "Faculty": { "$regex": "^T" } }
results = faculties.find(myquery)
for data in results:
    print(data)
# Out:
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %% [markdown]
# ## STEP 7 : Sort the data

# %%
# Sor the name ascending order
results = faculties.find().sort('Faculty')
for data in results:
    print(data)
# Out:
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}
# {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}

# %%
# Sor the name descending order
results = faculties.find().sort('Faculty',-1)
for data in results:
    print(data)
# Out:
# {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %% [markdown]
# ### STEP 7: Delete one or many documents in MongoDB

# %%
# Lets add some random data in faculties
random_data = [
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '6', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

faculties.insert_many(random_data)

# %%
# Lets delete one document in faculties
query_to_delete = {"Faculty": "XYZ"}

faculties.delete_one(query_to_delete)

# %%
# lets delete multiple record using delete many command
# Greate than or equal 4 record will delete
multi_query_to_delete = {"_id": {"$gte": "4"}}

faculties.delete_many(multi_query_to_delete)

# %% [markdown]
# > **NOTE**: In order to delete all the documents present in the collection you can just pass and empty dictionary as shown below: -
# ```python
# faculties.delete_many({})
# ```

# %% [markdown]
# ### STEP 8: Drop the entire collection

# %%
faculties.drop()

# %%
# Lets verify if the collection exists or not after dropping it
COLLECTION_NAME = "iNeuron_Faculties"
DB_NAME = "iNeuron"
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Faculties' in Database:'iNeuron' does not exists OR
#     no documents are present in the collection

# %% [markdown]
# ### STEP 9: Update

# %%
COLLECTION_NAME = "iNeuron_Products"

products = dataBase[COLLECTION_NAME]

all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f71'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f72'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f73'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f74'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
present_data = {'courseOffered': 'Machine Learning with Deployment'}
new_data = {"$set":{'courseOffered': 'ML and DL with Deployment'}}

# %%
products.update_one(present_data, new_data)

# %%
all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f71'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f72'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f73'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f74'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
present_data = {'companyName': 'iNeuron'}
new_data = {"$set": {'companyName': 'iNeuron.ai'}}

# %%
products.update_many(present_data, new_data)

all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f71'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f72'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f73'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f74'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
# Query & update
myquery = { "product": { "$regex": "^A" } }
newvalues = { "$set": { "product": "INeuron Online" } }

x = products.update_many(myquery, newvalues)

print(x.modified_count, "documents updated.")
# Out:
# 3 documents updated.

# %% [markdown]
# ### STEP 9: Set limit to view N records

# %%
N_records = 3

N_record = products.find().limit(N_records)

for idx, record in enumerate(N_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f71'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f72'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('6026bb2ab1f7dbd03d0f1f73'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}

# %% [raw]
# # What is the advantage of JSON format
#
# - Most of the API Support JSON FORMAT.
# - we can use the same output into directly database without any convertion.
# - From database we can import either jSON & CSV format - then we can use inside pandas.

# %% [markdown]
# # Assignment
# Insert the Iris data set & read

# %%
# Refer mongoDB Altas file for soultion
