# %% [markdown]
# ## 19.3.3 MongoDB Atlas
#
# * Atlas is a mongoDB service on cloud. It uses AWS, Azure and GCP cloud services to cater developers all around the globe for managing mongoDB databases.
# * Its a globally available cloud database service for all kinds of modern applications.
# * Visit [ATLAS HOMEPAGE](https://www.mongodb.com/cloud/atlas) for more details.
#
#
# Lets see how to utilize this services -

# %% [markdown]
# ### 19.3.3.1 Login or SignUp
#
# * Signup to your monngoDB atlas account at [here](https://account.mongodb.com/account/login)
# * Login with Google

# %% [markdown]
# ![login](mongo_img/atlas/01.login.png)
#
# ---

# %% [markdown]
# ### 19.3.3.2 Create Organisation
#
# ![CreateOrg](mongo_img/atlas/02.CreateOrg.png)

# %% [markdown]
# ![NameOrg](mongo_img/atlas/03NameOrg.png)
#
# ---

# %% [markdown]
# ### 19.3.3.3 Add Member or Create Organisation
#
#
# ![AddMemberCreateOrg](mongo_img/atlas/04.AddMemberCreateOrg.png)
#
# ---

# %% [markdown]
# ### 19.3.3.4 Create Project
#
# ![05CreatePro](mongo_img/atlas/05CreatePro.png)

# %% [markdown]
# ![06CreatePro2](mongo_img/atlas/06CreatePro2.png)

# %% [markdown]
# ![07CreateProAddMember](mongo_img/atlas/07CreateProAddMember.png)
#
# ---

# %% [markdown]
# ### 19.3.3.5 Choose a free shared cluster
#
# ![08BuildCluseter](mongo_img/atlas/08BuildCluseter.png)

# %% [markdown]
# * Select free cluster
#
# ![09CreateFreeCluster](mongo_img/atlas/09CreateFreeCluster.png)

# %% [markdown]
# * Select region and cloud service to host your database then create the cluster
#
# ![10CreateFreeStarterCluster](mongo_img/atlas/10CreateFreeStarterCluster.png)

# %% [markdown]
# ### 19.3.3.6 Click on Connect Cluster
# * Whitelist Your IP address
# - For that click allow acess from anywhere oprion
#
# * And Allow accesss
#
# ![11Click](mongo_img/atlas/11Click.png)

# %% [markdown]
# ![12WhitelistIP](mongo_img/atlas/12WhitelistIP.png)

# %% [markdown]
# ### 19.3.3.7 Add a database user
# * Save you user ID and Password
#
# ![13CreatemongoDBUSER](mongo_img/atlas/13CreatemongoDBUSER.png)

# %% [markdown]
# ### 19.3.3.8 Choose a connection method as application
# ![14Connect](mongo_img/atlas/14Connect.png)

# %% [markdown]
# ### 19.3.3.9 Select Python driver and its version
#
# ![15SelectPyDriver_version](mongo_img/atlas/15SelectPyDriver_version.png)

# %% [markdown]
# ### 19.3.3.10 Copy the connection string.
#
# * is will be used to connect to this Database
# - select full driver code example option as per attachemnt
#
# ![16CopyConnectionString](mongo_img/atlas/16CopyConnectionString.png)

# %% [markdown]
# ### 19.3.3.11 Go to Database access from the left Panel
#
# * Add a new user or edit the previlage of the current user to read and write access to the database
#
#
# ![17AddUser](mongo_img/atlas/17AddUser.png)

# %% [markdown]
# ![18CreatePWDCopy](mongo_img/atlas/18CreatePWDCopy.png)

# %% [markdown]
# ### 19.3.3.12 Current Users of your Database
#
# - Click database & click edit button & the drop down select read & write access
#
# ![19USERS_withRWaccess](mongo_img/atlas/19USERS_withRWaccess.png)

# %% [markdown]
# ### FINAL TEST

# %% [raw]
# ##!pip install pymongo[srv]

# %% [raw]
# #!pip install dnspython

# %%
import pymongo
import pandas as pd

# %%
USR = "thangaraj" # User created by us 'Test#12345'

# Auto Generated Password or Password set by You
# Update according to your set password for autogenerated password
PWD = "" 

DB_NAME = "iNeuron_AI" # Specifiy a Database Name

#mongodb+srv://thangaraj:<password>@cluster0.nsdo9.mongodb.net/<dbname>?retryWrites=true&w=majority
# Connection URL
#CONNECTION_URL = f"mongodb+srv://{USR}:{PWD}@cluster0.ksto3.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"
CONNECTION_URL = f"mongodb+srv://{USR}:{PWD}@cluster0.zvs9q.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"
# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]

# Create a Collection Name
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# Create a List of Records
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# insert above records in the collection
rec = collection.insert_many(list_of_records)

# Lets Verify all the record at once present in the record with all the fields
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('602769b17583cc1625b4e14b'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
# 1: {'_id': ObjectId('602769b17583cc1625b4e14c'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 2: {'_id': ObjectId('602769b17583cc1625b4e14d'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# 3: {'_id': ObjectId('60276fc97583cc1625b4e14e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
# 4: {'_id': ObjectId('60276ff97583cc1625b4e14f'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
# 5: {'_id': ObjectId('60276ff97583cc1625b4e150'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 6: {'_id': ObjectId('60276ff97583cc1625b4e151'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# 7: {'_id': ObjectId('602893e1cfd3afbf0552259d'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
# 8: {'_id': ObjectId('602893e1cfd3afbf0552259e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 9: {'_id': ObjectId('602893e1cfd3afbf0552259f'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# 10: {'_id': ObjectId('602893e2cfd3afbf055225a0'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
# 11: {'_id': ObjectId('602893e2cfd3afbf055225a1'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
# 12: {'_id': ObjectId('602893e2cfd3afbf055225a2'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 13: {'_id': ObjectId('602893e2cfd3afbf055225a3'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# 14: {'_id': ObjectId('60289c3fd152b6a7495e2652'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# 15: {'_id': ObjectId('60289c3fd152b6a7495e2653'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# 16: {'_id': ObjectId('60289c3fd152b6a7495e2654'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %% [markdown]
# > **NOTE**: If you get a DNS error then install the below python package -
# ```
# pip install pymongo[srv]
# ```
#
# > **NOTE**: if you get CongfigurationError: or try to install dnspython/ Already requirement get satisfied message- Please restart your kernal and clear output. & run.
#
# > **NOTE**: Always verif your password and userName as well.
#
# > **NOTE**: Also Verify that whether you have given read write permission to the present user or not.
# .

# %% [markdown]
# Lets Verify it in Atlas as well -
#
# - Click Cluster - Next click collection
#
# ![20FinalVerification](mongo_img/atlas/20FinalVerification.png)

# %% [markdown]
# > **NOTE**: After this you can follow the previous pymongo tutorial

# %%
client.list_database_names()
# Out:
# ['iNeuron_AI', 'iris', 'iris_logistic_classifier_model', 'admin', 'local']

# %% [markdown]
# #### We can connect the same via mangoDB campass
#
# 1.Click cluster
# 2.Click connect
# 3.click Connect using mongaDB Campass
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Select the URL
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Go to campass click connect & pass the URL
# For special charcter password needs to give ascii format example # we need to give %23
#
# ![image.png](attachment:image.png)

# %% [markdown]
# After connected
# ![image.png](attachment:image.png)

# %%
# let's verify whether we have our database in the list or not 
# Db name we have already defined in the above cell
# we'll use the following function:-

def checkExistence_DB(DB_NAME, client):
    """It verifies the existence of DB"""
    DBlist = client.list_database_names()
    if DB_NAME in DBlist:
        print(f"DB: '{DB_NAME}' exists")
        return True
    print(f"DB: '{DB_NAME}' not yet present OR no collection is present in the DB")
    return False


_ = checkExistence_DB(DB_NAME=DB_NAME, client=client)
# Out:
# DB: 'iNeuron_AI' exists

# %%
COLLECTION_NAME = "iNeuron_Products"
collection = dataBase[COLLECTION_NAME]

# %%
# let's verify whether we have our database in the list or not 
# we'll use the following function:-

def checkExistence_COL(COLLECTION_NAME, DB_NAME, db):
    """It verifies the existence of collection name in a database"""
    collection_list = db.list_collection_names()
    
    if COLLECTION_NAME in collection_list:
        print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' exists")
        return True
    
    print(f"Collection:'{COLLECTION_NAME}' in Database:'{DB_NAME}' does not exists OR \n\
    no documents are present in the collection")
    return False


_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Products' in Database:'iNeuron_AI' exists

# %%
# Create the single record & use insert_one command
record = {'companyName': 'iNeuron',
         'product': 'Affordable AI',
         'courseOffered': 'Deep Learning for Computer Vision',
         'comments':'from single record'}

collection.insert_one(record)

# %%
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Products' in Database:'iNeuron_AI' exists

# %%
# Create the multiple record & use insert many option
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

rec = collection.insert_many(list_of_records)

# %%
# lets print he unique ID that of the record that we have inserted -
inserted_IDs = rec.inserted_ids

for idx, unique_ids in enumerate(inserted_IDs):
    print(f"{idx}. {unique_ids}")
# Out:
# 0. 60289c41d152b6a7495e2656
# 1. 60289c41d152b6a7495e2657
# 2. 60289c41d152b6a7495e2658

# %%
# Getting id as string
agent_id2 = [str(id) for id in collection.find().distinct('_id')]
agent_id2
# Out:
# ['602769b17583cc1625b4e14b',
#  '602769b17583cc1625b4e14c',
#  '602769b17583cc1625b4e14d',
#  '60276fc97583cc1625b4e14e',
#  '60276ff97583cc1625b4e14f',
#  '60276ff97583cc1625b4e150',
#  '60276ff97583cc1625b4e151',
#  '602893e1cfd3afbf0552259d',
#  '602893e1cfd3afbf0552259e',
#  '602893e1cfd3afbf0552259f',
#  '602893e2cfd3afbf055225a0',
#  '602893e2cfd3afbf055225a1',
#  '602893e2cfd3afbf055225a2',
#  '602893e2cfd3afbf055225a3',
#  '60289c3fd152b6a7495e2652',
#  '60289c3fd152b6a7495e2653',
#  '60289c3fd152b6a7495e2654',
#  '60289c40d152b6a7495e2655',
#  '60289c41d152b6a7495e2656',
#  '60289c41d152b6a7495e2657',
#  '60289c41d152b6a7495e2658']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#  Create the new collection and  give our own id
#  Select the new collection & observe the same in UI
#  if we re -execute error will diplay
# go to UI & delete each record manually & re execute.
COLLECTION_NAME = "iNeuron_Faculties"
faculties = dataBase[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "1",
    "companyName": "iNeuron",
    "Faculty": "Sudhanshu Kumar",
    'PhoneNumber':'001'},
    {"_id": "2",
    "companyName": "iNeuron",
    "Faculty": "Virat Sagar",
    'PhoneNumber':'002'},
    {"_id": "3",
    "companyName": "iNeuron",
    "Faculty": "Thangaraj",
    'PhoneNumber':'003'},
]
# database variable object creation 
faculties_record = faculties.insert_many(list_of_records_user_defined_id)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Get the first record from the faculties collection
find_first_record = faculties.find_one()

print(f"The first record of collection: \n{COLLECTION_NAME} is=\
\n{find_first_record}")
# Out:
# The first record of collection:
# iNeuron_Faculties is=
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# find all the record at once present in thr record with all the fields
all_record = faculties.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}
# 1: {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# 2: {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# find all the record at once present in the record with SPECIFIC fields
all_record = faculties.find({}, {"Faculty"})

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'Faculty': 'Sudhanshu Kumar'}
# 1: {'_id': '2', 'Faculty': 'Virat Sagar'}
# 2: {'_id': '3', 'Faculty': 'Thangaraj'}

# %%
# find all the record at once present in the record with mutiple mentioned fields
all_record = faculties.find({}, {"Faculty",'PhoneNumber',})

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': '1', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}
# 1: {'_id': '2', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# 2: {'_id': '3', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# Query based on id
query1 = {"_id": '1'}

results = faculties.find(query1)
for data in results:
    print(data)
# Out:
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# Query based on phone number
query1 = {'PhoneNumber': '003'}

results = faculties.find(query1)
for data in results:
    print(data)
# Out:
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# List all the record greate than one
query2 = {"_id": {"$gt": "1"}}

results = faculties.find(query2)
for data in results:
    print(data)
# Out:
# {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# Print less than 2
query2 = {"_id": {"$lt": "2"}}

results = faculties.find(query2)
for data in results:
    print(data)
# Out:
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# Print the Faculty start with T using regular expression
myquery = { "Faculty": { "$regex": "^T" } }
results = faculties.find(myquery)
for data in results:
    print(data)
# Out:
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}

# %%
# Sor the name descending order
results = faculties.find().sort('Faculty',-1)
for data in results:
    print(data)
# Out:
# {'_id': '2', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar', 'PhoneNumber': '002'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'Thangaraj', 'PhoneNumber': '003'}
# {'_id': '1', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar', 'PhoneNumber': '001'}

# %%
# Lets add some random data in faculties
random_data = [
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '6', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

faculties.insert_many(random_data)

# %%
# Lets delete one document in faculties
query_to_delete = {"Faculty": "XYZ"}

faculties.delete_one(query_to_delete)

# %%
# lets delete multiple record using delete many command
# Greate than or equal 4 record will delete
multi_query_to_delete = {"_id": {"$gte": "4"}}

faculties.delete_many(multi_query_to_delete)

# %%
# Drop entire collection
faculties.drop()

# %%
# Lets verify if the collection exists or not after dropping it
COLLECTION_NAME = "iNeuron_Faculties"
DB_NAME = "iNeuron"
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)
# Out:
# Collection:'iNeuron_Faculties' in Database:'iNeuron' does not exists OR
#     no documents are present in the collection

# %%
# Update
COLLECTION_NAME = "iNeuron_Products"

products = dataBase[COLLECTION_NAME]

all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('602769b17583cc1625b4e14b'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14c'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14d'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60276fc97583cc1625b4e14e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e14f'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e150'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e151'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259d'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259f'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a0'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a1'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a2'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a3'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2652'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2653'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2654'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c40d152b6a7495e2655'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2656'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2657'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2658'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
present_data = {'courseOffered': 'Machine Learning with Deployment'}
new_data = {"$set":{'courseOffered': 'ML and DL with Deployment'}}

# %%
products.update_one(present_data, new_data)

# %%
all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('602769b17583cc1625b4e14b'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14c'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14d'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60276fc97583cc1625b4e14e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e14f'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e150'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e151'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259d'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259f'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a0'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a1'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a2'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a3'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2652'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2653'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2654'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c40d152b6a7495e2655'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2656'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2657'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2658'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
# All record
present_data = {'companyName': 'iNeuron'}
new_data = {"$set": {'companyName': 'iNeuron.ai'}}
products.update_many(present_data, new_data)

all_record = products.find()

for idx, record in enumerate(all_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('602769b17583cc1625b4e14b'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14c'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14d'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60276fc97583cc1625b4e14e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e14f'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e150'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60276ff97583cc1625b4e151'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259d'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259e'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e1cfd3afbf0552259f'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a0'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a1'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a2'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602893e2cfd3afbf055225a3'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2652'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2653'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c3fd152b6a7495e2654'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# {'_id': ObjectId('60289c40d152b6a7495e2655'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for Computer Vision', 'comments': 'from single record'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2656'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2657'), 'companyName': 'iNeuron.ai', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('60289c41d152b6a7495e2658'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
# Query & update
myquery = { "product": { "$regex": "^A" } }
newvalues = { "$set": { "product": "INeuron Online" } }

x = products.update_many(myquery, newvalues)

print(x.modified_count, "documents updated.")
# Out:
# 5 documents updated.

# %%
# Set limit
N_records = 3

N_record = products.find().limit(N_records)

for idx, record in enumerate(N_record):
    print(f"{record}\n")
# Out:
# {'_id': ObjectId('602769b17583cc1625b4e14b'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'ML and DL with Deployment'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14c'), 'companyName': 'iNeuron.ai', 'product': 'INeuron Online', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('602769b17583cc1625b4e14d'), 'companyName': 'iNeuron.ai', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %% [markdown]
# ## Assignment:
# Push the iris dataset in to mangoDB & read

# %%
import json
USR = "thangaraj" # User created by us 'Test#12345'

# Auto Generated Password or Password set by You
# Update according to your set password for autogenerated password
PWD = "" 

DB_NAME = "iris" # Specifiy a Database Name

#mongodb+srv://thangaraj:<password>@cluster0.nsdo9.mongodb.net/<dbname>?retryWrites=true&w=majority
# Connection URL
CONNECTION_URL = f"mongodb+srv://{USR}:{PWD}@cluster0.zvs9q.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"
try:
# Establish a connection with mongoDB
    client = pymongo.MongoClient(CONNECTION_URL)
    print("Connected successfully!!!")
except:
    print("Could not connect to MongoDB")
# Create a DB
dataBase = client[DB_NAME]

# Create a Collection Name
COLLECTION_NAME = "iris_data"
collection = dataBase[COLLECTION_NAME]
# Out:
# Connected successfully!!!

# %%
# Push the CSV Data
data = pd.read_csv('iris.csv',encoding = 'ISO-8859-1')   # loading csv file
data_json = json.loads(data.to_json(orient='records'))   # Convert the data into json format
collection.delete_many # delete the already avaliable records
collection.insert_many(data_json)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_record = collection.find()
df = pd.DataFrame(list(all_record))
df.head()
# Out:
#                         _id  petal_length  petal_width  sepal_length  \
# 0  602892509f4cf43e2d4cd606           1.4          0.2           5.1
# 1  602892509f4cf43e2d4cd607           1.4          0.2           4.9
# 2  602892509f4cf43e2d4cd608           1.3          0.2           4.7
# 3  602892509f4cf43e2d4cd609           1.5          0.2           4.6
# 4  602892509f4cf43e2d4cd60a           1.4          0.2           5.0
#
#    sepal_width species
# 0          3.5  setosa
# 1          3.0  setosa
# 2          3.2  setosa
# 3          3.1  setosa
# 4          3.6  setosa

# %%
# Convert dataframe to numpy array
X = df[['petal_length','petal_width','sepal_length','sepal_width']].to_numpy()
y = df['species'].to_numpy()

# %%
# Saving model into MongoDB
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logistic_classifier_model = LogisticRegression(random_state = 0, solver='lbfgs', multi_class='auto')
logistic_classifier_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
def save_model_to_db(model, client, db, dbconnection, model_name):
    import pickle
    import time
    import pymongo
    #pickling the model
    pickled_model = pickle.dumps(model)
    
    #saving model to mongoDB
    # creating connection
    myclient = pymongo.MongoClient(client)
    
    #creating database in mongodb
    mydb = myclient[db]
    
    #creating collection
    mycon = mydb[dbconnection]
    info = mycon.insert_one({model_name: pickled_model, 'name': model_name, 'created_time':time.time()})
    print(info.inserted_id, ' saved with this id successfully!')
    
    details = {
        'inserted_id':info.inserted_id,
        'model_name':model_name,
        'created_time':time.time()
    }
    
    return details

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def load_saved_model_from_db(model_name, client, db, dbconnection):
    import pickle
    import time
    import pymongo
    json_data = {}
    
    #saving model to mongoDB
    # creating connection
    myclient = pymongo.MongoClient(client)
    
    #creating database in mongodb
    mydb = myclient[db]
    
    #creating collection
    mycon = mydb[dbconnection]
    data = mycon.find({'name': model_name})
    
    
    for i in data:
        json_data = i
    #fetching model from db
    pickled_model = json_data[model_name]
    
    return pickle.loads(pickled_model)

# %%
#saving model to mongoDB
CONNECTION_URL = f"mongodb+srv://{USR}:{PWD}@cluster0.zvs9q.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"
DB_NAME = "iris_logistic_classifier_model"  
COLLECTION_NAME = "iris_data"
MODEL_NAME = 'my_logistic'
# Model name,Connection url,DB Name
details = save_model_to_db(model = logistic_classifier_model, client = CONNECTION_URL, db = DB_NAME, 
                 dbconnection = COLLECTION_NAME, model_name = MODEL_NAME)
# Out:
# 60289c5fd152b6a7495e26f1  saved with this id successfully!

# %%
#fetching model from mongo
log_model  = load_saved_model_from_db(model_name = details['model_name'], client = CONNECTION_URL, 
                         db = DB_NAME, dbconnection = COLLECTION_NAME)

# %%
# Predicting the Test set results
import numpy as np
y_pred = log_model.predict(X_test)
# Predict probabilities
probs_y=log_model.predict_proba(X_test)
### Print results 
probs_y = np.round(probs_y, 2)
res = "{:<10} | {:<10} | {:<10} | {:<13} | {:<5}".format("y_test", "y_pred", "Setosa(%)", "versicolor(%)", "virginica(%)\n")
res += "-"*65+"\n"
res += "\n".join("{:<10} | {:<10} | {:<10} | {:<13} | {:<10}".format(x, y, a, b, c) for x, y, a, b, c in zip(y_test, y_pred, probs_y[:,0], probs_y[:,1], probs_y[:,2]))
res += "\n"+"-"*65+"\n"
print(res)
# Out:
# y_test     | y_pred     | Setosa(%)  | versicolor(%) | virginica(%)
# -----------------------------------------------------------------
# virginica  | virginica  | 0.0        | 0.12          | 0.88
# virginica  | virginica  | 0.0        | 0.32          | 0.68
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# versicolor | virginica  | 0.0        | 0.47          | 0.53
# setosa     | setosa     | 0.97       | 0.03          | 0.0
# virginica  | virginica  | 0.0        | 0.36          | 0.64
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.0        | 0.83          | 0.16
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.01       | 0.92          | 0.07
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.33          | 0.67
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# versicolor | versicolor | 0.03       | 0.79          | 0.18
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.0        | 0.99          | 0.01
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.0        | 0.88          | 0.12
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.14          | 0.86
# versicolor | versicolor | 0.03       | 0.85          | 0.12
# virginica  | virginica  | 0.0        | 0.07          | 0.93
# versicolor | versicolor | 0.0        | 0.6           | 0.4
# versicolor | versicolor | 0.01       | 0.94          | 0.05
# versicolor | versicolor | 0.0        | 0.55          | 0.45
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.27          | 0.73
# virginica  | virginica  | 0.0        | 0.14          | 0.86
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# virginica  | virginica  | 0.0        | 0.03          | 0.97
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# versicolor | versicolor | 0.0        | 0.96          | 0.04
# virginica  | virginica  | 0.0        | 0.02          | 0.98
# virginica  | virginica  | 0.0        | 0.1           | 0.9
# versicolor | versicolor | 0.05       | 0.94          | 0.01
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.01       | 0.81          | 0.18
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# setosa     | setosa     | 0.97       | 0.03          | 0.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# versicolor | versicolor | 0.0        | 0.87          | 0.13
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.04       | 0.95          | 0.01
# versicolor | versicolor | 0.1        | 0.9           | 0.0
# virginica  | virginica  | 0.0        | 0.06          | 0.94
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.02          | 0.98
# versicolor | versicolor | 0.01       | 0.81          | 0.18
# versicolor | versicolor | 0.04       | 0.9           | 0.06
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.14          | 0.86
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.0        | 0.87          | 0.13
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.0        | 0.88          | 0.12
# versicolor | versicolor | 0.1        | 0.9           | 0.0
# versicolor | virginica  | 0.0        | 0.4           | 0.59
# virginica  | virginica  | 0.0        | 0.06          | 0.94
# virginica  | virginica  | 0.0        | 0.04          | 0.96
# versicolor | versicolor | 0.01       | 0.98          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.21          | 0.79
# versicolor | versicolor | 0.0        | 0.97          | 0.03
# virginica  | virginica  | 0.0        | 0.28          | 0.72
# versicolor | versicolor | 0.0        | 0.89          | 0.1
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.04       | 0.93          | 0.02
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.27          | 0.73
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# versicolor | versicolor | 0.01       | 0.91          | 0.08
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.0        | 0.6           | 0.4
# versicolor | virginica  | 0.0        | 0.4           | 0.59
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# versicolor | versicolor | 0.03       | 0.85          | 0.12
# versicolor | versicolor | 0.02       | 0.95          | 0.03
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.02          | 0.98
# versicolor | versicolor | 0.0        | 0.83          | 0.16
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.02          | 0.98
# versicolor | virginica  | 0.0        | 0.34          | 0.66
# versicolor | versicolor | 0.01       | 0.94          | 0.05
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# versicolor | versicolor | 0.04       | 0.93          | 0.02
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.02       | 0.98          | 0.0
# virginica  | virginica  | 0.0        | 0.36          | 0.64
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.06          | 0.94
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.1           | 0.9
# virginica  | virginica  | 0.0        | 0.36          | 0.64
# versicolor | versicolor | 0.01       | 0.97          | 0.02
# versicolor | versicolor | 0.02       | 0.95          | 0.03
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.04          | 0.96
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.06          | 0.94
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.07          | 0.93
# versicolor | versicolor | 0.03       | 0.79          | 0.18
# virginica  | virginica  | 0.0        | 0.06          | 0.94
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# versicolor | versicolor | 0.01       | 0.97          | 0.02
# virginica  | virginica  | 0.0        | 0.07          | 0.93
# versicolor | versicolor | 0.0        | 0.6           | 0.4
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.0        | 0.82          | 0.18
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.04       | 0.93          | 0.02
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# versicolor | versicolor | 0.01       | 0.98          | 0.0
# versicolor | versicolor | 0.0        | 0.93          | 0.07
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.03       | 0.79          | 0.18
# versicolor | versicolor | 0.01       | 0.94          | 0.05
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.13          | 0.87
# versicolor | versicolor | 0.01       | 0.94          | 0.05
# versicolor | versicolor | 0.0        | 0.96          | 0.04
# versicolor | versicolor | 0.01       | 0.91          | 0.08
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.03          | 0.97
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.04          | 0.96
# virginica  | virginica  | 0.0        | 0.03          | 0.97
# versicolor | versicolor | 0.01       | 0.9           | 0.09
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.14          | 0.86
# versicolor | versicolor | 0.0        | 0.83          | 0.16
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# versicolor | versicolor | 0.0        | 0.82          | 0.18
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.05       | 0.95          | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.03          | 0.97
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# virginica  | virginica  | 0.0        | 0.2           | 0.8
# setosa     | setosa     | 0.99       | 0.01          | 0.0
# virginica  | virginica  | 0.0        | 0.0           | 1.0
# versicolor | virginica  | 0.0        | 0.34          | 0.66
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.01       | 0.94          | 0.05
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 0.98       | 0.02          | 0.0
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# versicolor | versicolor | 0.01       | 0.98          | 0.01
# versicolor | versicolor | 0.01       | 0.98          | 0.0
# virginica  | virginica  | 0.0        | 0.08          | 0.92
# virginica  | virginica  | 0.0        | 0.01          | 0.99
# setosa     | setosa     | 1.0        | 0.0           | 0.0
# versicolor | versicolor | 0.0        | 0.95          | 0.05
# -----------------------------------------------------------------

# %% [markdown]
# ### REFER OFFICIAL DOCS-
# [OFFCIAL DOC LINK](https://docs.atlas.mongodb.com/data-explorer/)
