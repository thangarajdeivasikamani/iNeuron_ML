# %% [markdown]
# **ASSIGNMENT : 2**

# %% [markdown]
# **Problem Statement 1:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Print the given row number pattern in forward and reverse.
rows = 5
for row in range(1,rows+1):
    for i in range(row):
        print('*', end=" ")  # print outer loop number # Here end command helps to print the for loop content in the same line
    print(" ") #  #line after each row to display pattern correctly
for row in range(rows+1,0,-1):
    for i in range(row):
        print('*', end=" ")  # print outer loop number reverse order # Here end command helps to print the for loop content in the same line
    print(" ") # #line after each row to display pattern correctly
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# **Problem Statement 2:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Using function and error capture 
def reverse_charater(input_string):
      if(len(input_string) == 0):
         print('Given input is empty')
      else:
        return(input_string[::-1])
input_string = str(input("Input Word: "))
reveresed_string = reverse_charater(input_string)
print("Output: ",reveresed_string)
# Out:
# Input Word: ineuron
# Output:  norueni

# %%
# Using string index operation
input_string = str(input("Input Word: "))
print("Output: ",input_string[::-1])
# Out:
# Input Word: ineuron
# Output:  norueni
