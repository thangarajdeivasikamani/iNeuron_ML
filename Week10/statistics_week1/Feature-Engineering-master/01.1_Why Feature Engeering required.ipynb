# %% [raw]
# Each feature has magnitude and units
# units means cm or kg
# mangnitude means the actual value 150, 60
# some algorthms performe very well if the data on same scale.
# If we plot it will show like outliers
# Example KNN use Euclidean distance internally -if the features are  differnt scale than the performance /prediction of algo
# will be degrade.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2020/07/types-of-feature-transformation-and-scaling/
#
#
# Various feature scaling avalibale
#
#
#     Why do we need Feature Transformation and Scaling?
#     MinMax Scaler
#     Standard Scaler
#     MaxAbsScaler
#     Robust Scaler
#     Quantile Transformer Scaler
#     Log Transformation
#     Power Transformer Scaler
#     Unit Vector Scaler/Normalizer

# %% [raw]
# The algorithm will affect because of feature scaling:
#
# 1. Linear regression - Gradient decent- if same sacel the converge will happen properly
# 2. KNN, K-mean - Euclidean distance - Run very fast
# 3. For Deep learning it's compulsary.
# 4. ANN,CNN,RNN
#    in CNN- input as pixel- 0-255 convert 0 -to 1 using unit scale

# %% [markdown]
# ### When should not use feature scaling?
#
# 1. Decision Tree
# 2. Random Forest
# 3. XGBOOST - Ensample Technique
#
# Here we are just forming the Tree based on feature, So whether scaling down or not will not impact.
