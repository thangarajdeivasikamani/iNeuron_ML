# %% [markdown]
# ## Chi-Square Test-
#
# The test is applied when you have two categorical variables from a single population. It is used to determine whether there is a significant association between the two variables.

# %%
import scipy.stats as stats

# %%
import seaborn as sns
import pandas as pd
import numpy as np
dataset=sns.load_dataset('tips')

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset_table=pd.crosstab(dataset['sex'],dataset['smoker'])
print(dataset_table)
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
dataset_table.values
# Out:
# array([[60, 97],
#        [33, 54]], dtype=int64)

# %%
#Observed Values
Observed_Values = dataset_table.values 
print("Observed Values :-\n",Observed_Values)
# Out:
# Observed Values :-
#  [[60 97]
#  [33 54]]

# %%
val=stats.chi2_contingency(dataset_table)

# %%
val
# Out:
# (0.008763290531773594, 0.925417020494423, 1, array([[59.84016393, 97.15983607],
#         [33.15983607, 53.84016393]]))

# %%
Expected_Values=val[3]

# %%
no_of_rows=len(dataset_table.iloc[0:2,0])
no_of_columns=len(dataset_table.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",ddof)
alpha = 0.05
# Out:
# Degree of Freedom:- 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
chi_square_statistic=chi_square[0]+chi_square[1]

# %%
print("chi-square statistic:-",chi_square_statistic)
# Out:
# chi-square statistic:- 0.001934818536627623

# %%
critical_value=chi2.ppf(q=1-alpha,df=ddof)
print('critical_value:',critical_value)
# Out:
# critical_value: 3.841458820694124

# %%
#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
print('p-value:',p_value)
# Out:
# p-value: 0.964915107315732
# Significance level:  0.05
# Degree of Freedom:  1
# p-value: 0.964915107315732

# %%
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
    
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Retain H0,There is no relationship between 2 categorical variables
# Retain H0,There is no relationship between 2 categorical variables

# %% [markdown]
# ## T Test
#
# Population standardard deviation is not avaliable use T-Test
#
# A t-test is a type of inferential statistic which is used to determine if there is a significant difference between the means of two groups which may be related in certain features
#
# T-test has 2 types : 1. one sampled t-test 2. two-sampled t-test.

# %% [markdown]
# ##  One-sample T-test with Python
#
# Hypothesis : The test will tell us whether means of the sample and the population are different
#
# ![image.png](attachment:image.png)

# %%
ages=[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
len(ages)
# Out:
# 32

# %%
# Need to calculate the population mean
import numpy as np
ages_mean=np.mean(ages)
print(ages_mean)
# Out:
# 30.34375

# %%
## Lets take sample,we can choose 20 sample size also
sample_size=10
# pick 10 random age sample
age_sample=np.random.choice(ages,sample_size)

# %%
age_sample
# Out:
# array([23, 18, 16, 55, 27, 23, 55, 20, 55, 18])

# %%
# One sample so impport 1 sample test
from scipy.stats import ttest_1samp

# %%
# Sample & mean as input
ttest,p_value=ttest_1samp(age_sample,30)

# %%
print(p_value)
# Out:
# 0.8553160254145091

# %%
print(ttest)
# Out:
# 0.18764665626020038

# %%
# P value is not less than 0.05 so we are accepting
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %%
# Another sample:
age_sample1 = [1,5,10]
# Differnt sample & population mean
ttest,p_value=ttest_1samp(age_sample1,30)
print(p_value)
print(ttest)
# P value is  less than 0.05 so we are rejecting
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# 0.010956774290295264
# -9.474729115034302
#  we are rejecting null hypothesis

# %% [markdown]
# ## Some More Examples
# Consider the age of students in a college and in Class A

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import math
np.random.seed(6)
# Creating poisson distribution
# 1500 is population 
# 60 is sample
# location start from 18
school_ages=stats.poisson.rvs(loc=18,mu=35,size=1500)
classA_ages=stats.poisson.rvs(loc=18,mu=30,size=60)

# %%
classA_ages.mean()
# Out:
# 46.9

# %%
_,p_value=stats.ttest_1samp(a=classA_ages,popmean=school_ages.mean())

# %%
# here p value is very very less
p_value
# Out:
# 1.139027071016194e-13

# %%
school_ages.mean()
# Out:
# 53.303333333333335

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %%
#Null Hypothesis: mean of age is should be equal to class of A age

# %% [markdown]
# ## Two-sample T-test With Python
# The Independent Samples t Test or 2-sample t-test compares the means of two independent groups in order to determine whether there is statistical evidence that the associated population means are significantly different. The Independent Samples t Test is a parametric test. This test is also known as: Independent t Test
#
# ![image.png](attachment:image.png)

# %%
np.random.seed(12)
ClassB_ages=stats.poisson.rvs(loc=18,mu=33,size=60)
ClassB_ages.mean()
# Out:
# 50.63333333333333

# %%
ClassB_ages
# Out:
# array([44, 47, 60, 65, 47, 52, 56, 56, 44, 48, 50, 47, 55, 49, 50, 50, 50,
#        41, 53, 47, 39, 50, 52, 43, 53, 51, 59, 53, 51, 46, 41, 53, 63, 53,
#        48, 65, 63, 54, 49, 53, 48, 45, 49, 59, 50, 51, 56, 45, 56, 43, 43,
#        47, 54, 48, 45, 41, 60, 48, 51, 49])

# %%
# two independent sample & we are comparing 
_,p_value=stats.ttest_ind(a=classA_ages,b=ClassB_ages,equal_var=False)

# %%
print(p_value)
# Out:
# 0.00039942095100859375

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %% [markdown]
# ## Paired T-test With Python
# When you want to check how different samples from the same group are, you can go for a paired T-test

# %% [markdown]
# https://libguides.library.kent.edu/SPSS/PairedSamplestTest

# %%
#Same population - Take differnt sample check -Use Paired T -Test
#Example: Company do the 10 add , sample 1 we will take 2 & sample 2 we will take 3 and compare which one is effective

# %%
weight1=[25,30,28,35,28,34,26,29,30,26,28,32,31,30,45]
weight2=weight1+stats.norm.rvs(scale=5,loc=-1.25,size=15)

# %%
print(weight1)
print(weight2)
# Out:
# [25, 30, 28, 35, 28, 34, 26, 29, 30, 26, 28, 32, 31, 30, 45]
# [30.57926457 34.91022437 29.00444617 30.54295091 19.86201983 37.57873174
#  18.3299827  21.3771395  36.36420881 32.05941216 26.93827982 29.519014
#  26.42851213 30.50667769 41.32984284]

# %%
weight_df=pd.DataFrame({"weight_10":np.array(weight1),
                         "weight_20":np.array(weight2),
                       "weight_change":np.array(weight2)-np.array(weight1)})

# %%
weight_df
# Out:
#     weight_10  weight_20  weight_change
# 0          25  30.579265       5.579265
# 1          30  34.910224       4.910224
# 2          28  29.004446       1.004446
# 3          35  30.542951      -4.457049
# 4          28  19.862020      -8.137980
# 5          34  37.578732       3.578732
# 6          26  18.329983      -7.670017
# 7          29  21.377139      -7.622861
# 8          30  36.364209       6.364209
# 9          26  32.059412       6.059412
# 10         28  26.938280      -1.061720
# 11         32  29.519014      -2.480986
# 12         31  26.428512      -4.571488
# 13         30  30.506678       0.506678
# 14         45  41.329843      -3.670157

# %%
# Rel is check the two ttest relation
_,p_value=stats.ttest_rel(a=weight1,b=weight2)

# %%
print(p_value)
# Out:
# 0.5732936534411279

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %% [markdown]
# ## Correlation

# %%
import seaborn as sns
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue = 'species')

# %% [markdown]
# ## Anova Test(F-Test)
#
# - Comnpare mean of two or more  groups - we will use Anova
# - The t-test works well when dealing with two groups, but sometimes we want to compare more than two groups at the same time.
#
#
# For example, if we wanted to test whether petal_width age differs based on some categorical variable like species, we have to compare the means of each level or group the variable

# %% [markdown]
# ### One Way F-test(Anova) :-
# It tell whether two or more groups are similar or not based on their mean similarity and f-score.
#
# Example : there are 3 different category of iris flowers and their petal width and need to check whether all 3 group are similar or not

# %%
import seaborn as sns
df1=sns.load_dataset('iris')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [raw]
# Factor- Iris
# sepal_length 	sepal_width 	petal_length 	petal_width 	species - Five level - First 4 are independ species- Dependend
# So it's factorial
#
# Consider only first 4 feature
#
# All are independent - One way
#
# Consider onlt 4 feature - But both are co-related - Then repeated measure

# %%
df_anova = df1[['petal_width','species']]

# %%
grps = pd.unique(df_anova.species.values)

# %%
grps
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
d_data = {grp:df_anova['petal_width'][df_anova.species == grp] for grp in grps}

# %%
d_data
# Out:
# {'setosa': 0     0.2
#  1     0.2
#  2     0.2
#  3     0.2
#  4     0.2
#  5     0.4
#  6     0.3
#  7     0.2
#  8     0.2
#  9     0.1
#  10    0.2
#  11    0.2
#  12    0.1
#  13    0.1
#  14    0.2
#  15    0.4
#  16    0.4
#  17    0.3
#  18    0.3
#  19    0.3
#  20    0.2
#  21    0.4
#  22    0.2
#  23    0.5
#  24    0.2
#  25    0.2
#  26    0.4
#  27    0.2
#  28    0.2
#  29    0.2
#  30    0.2
#  31    0.4
#  32    0.1
#  33    0.2
#  34    0.2
#  35    0.2
#  36    0.2
#  37    0.1
#  38    0.2
#  39    0.2
#  40    0.3
#  41    0.3
#  42    0.2
#  43    0.6
#  44    0.4
#  45    0.3
#  46    0.2
#  47    0.2
#  48    0.2
#  49    0.2
#  Name: petal_width, dtype: float64,
#  'versicolor': 50    1.4
#  51    1.5
#  52    1.5
#  53    1.3
#  54    1.5
#  55    1.3
#  56    1.6
#  57    1.0
#  58    1.3
#  59    1.4
#  60    1.0
#  61    1.5
#  62    1.0
#  63    1.4
#  64    1.3
#  65    1.4
#  66    1.5
#  67    1.0
#  68    1.5
#  69    1.1
#  70    1.8
#  71    1.3
# ...

# %%
F, p = stats.f_oneway(d_data['setosa'], d_data['versicolor'], d_data['virginica'])

# %%
print(p)
# Out:
# 4.169445839443116e-85

# %%
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# reject null hypothesis

# %%
## repeate Test

# %%
Check internet

# %% [markdown]
# http://statisticslectures.com/topics/onewayanova/
