# %%
## Importing Necessary Modules
import os
import requests # to get image from the web
import shutil # to save it locally
import json
import ssl
from urllib.request import Request,urlopen as uReq
from bs4 import BeautifulSoup as bs

# %%
#pip install django

# %%
# Ingore the SSL warning
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verfy_mode =ssl.CERT_NONE

# %%
searchString ='msi'
flipkart_url = "https://www.flipkart.com/search?q=" + searchString
uClient = uReq(flipkart_url)
flipkartPage = uClient.read()
uClient.close()
flipkart_html = bs(flipkartPage, 'html.parser')
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
pagesize_content = flipkart_html.find("div", {"class": "_2MImiq"})
pagesize_content.prettify()
pagesize_info = pagesize_content.span.contents[0]
print(pagesize_info)
res = [int(i) for i in pagesize_info.split() if i.isdigit()]
page_size= res[-1]
page_size = 5
print(page_size)
count = 0
# Out:
# Page 1 of 188
# 5

# %%
# Open a local file with wb ( write binary ) permission.
if os.path.exists("product_image"):
    shutil.rmtree('product_image', ignore_errors=True)
else:
    os.makedirs("product_image")
for n in list(range(page_size)):
        print("Entering into page:",n+1)
        #Navigate the required page
        page_url = "https://www.flipkart.com/search?q="+searchString+"+&amp%3Bas=on&amp%3Bas-show=on&amp%3Botracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&amp%3Botracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&amp%3Bas-pos=1&amp%3Bas-type=HISTORY&amp%3BsuggestionId=samsung+&amp%3BrequestId=3deaa522-51bf-4a70-a7fc-d86c0a81128d&amp%3Bpage=4&page="+str(n)
        eachpage = requests.get(page_url)
        eachpages = bs(eachpage.content)
        #Extratc the product size from the each page
        container = eachpages.find('span',attrs={"class":'_10Ermr'})
        page_product_start_count=(int(container.text.split(' ')[1]))-1
        page_product_end_count = (int(container.text.split(' ')[3]))
        products_per_page = page_product_end_count-page_product_start_count
        print("products_per_page:",products_per_page)
        #Extarct the top level class content
        container = eachpages.findAll("div",{"class":"_1YokD2 _3Mn1Gg"})
        print(len(raw_bigboxes))
        # Navigate to product list section
        raw_bigboxes = container[1].findAll("div", {"class": "_1AtVbE col-12-12"})
        print(len(bigboxes))
        #Eliminate the last two uncessary product info link
        bigboxes=raw_bigboxes[: len(raw_bigboxes)-2]
        #print(len(bigboxes))
        imageFiles = []

        count = 0
        for i in list(range(products_per_page)):
                if(count == 25):break
                #print("Entering into product",i+1)
                box = bigboxes[i]
                productLink = "https://www.flipkart.com" + box.div.div.div.a['href']
                product_open_page = requests.get(productLink) 
                product_html = bs(product_open_page.text, 'html.parser')
                #scrapping the image url from flipkart
                try:
                    product_image_url = product_html.find_all('div', {'class': 'q6DClP'})[0].attrs['style']
                    # https://rukminim1.flixcart.com/image/128/128/ke353m80/computer/g/r/s/msi-original-imafuuszq3jm8mry.jpeg?q=70 
                    # Getting large image update the size
                    product_image_url=product_image_url[product_image_url.find('(')+1:-1].replace('128','352')
                    # print(product_image_url)

                except:
                    product_image_url = 'No image availbel for ' + searchString
                #Set the file name to save
                filename = product_image_url.split("/")[-1].split("?")[0]
                #print(filename)
                # Open the url image, set stream to True, this will return the stream content.
                try:
                    r = requests.get(product_image_url, stream = True)
                    if r.status_code == 200:
                    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
                        r.raw.decode_content = True     
                        try:
                             with open("./product_image/"+filename,'wb') as f:
                                shutil.copyfileobj(r.raw, f)
                                #print('Image sucessfully Downloaded: ',filename)
                        except Exception as e:
                                print ("could not load : "+filename)
                                print (e)

                except:
                    print('Image page not able to retreived')
                count = count + 1
# Out:
# Entering into page: 1
# products_per_page: 40
# 42
# 40
# Entering into product 1
# Entering into product 2
# Entering into product 3
# Entering into product 4
# Entering into product 5
# Entering into product 6
# Entering into product 7
# Entering into product 8
# Entering into product 9
# Entering into product 10
# Entering into product 11
# Entering into product 12
# Entering into product 13
# Entering into product 14
# Entering into product 15
# Entering into product 16
# Entering into product 17
# Entering into product 18
# Entering into product 19
# Entering into product 20
# Entering into product 21
# Entering into product 22
# Entering into product 23
# Entering into product 24
# Entering into product 25
# Entering into page: 2
# products_per_page: 40
# 42
# 40
# Entering into product 1
# Entering into product 2
# Entering into product 3
# Entering into product 4
# Entering into product 5
# Entering into product 6
# Entering into product 7
# Entering into product 8
# ...

# %%
#scrapping the image url from flipkart
try:
    product_image_url = product_html.find_all('div', {'class': 'q6DClP'})[0].attrs['style']
    # https://rukminim1.flixcart.com/image/128/128/ke353m80/computer/g/r/s/msi-original-imafuuszq3jm8mry.jpeg?q=70 
    # Getting large image update the size
    product_image_url=product_image_url[product_image_url.find('(')+1:-1].replace('128','352')
    # print(product_image_url)

except:
    product_image_url = 'No image availbel for ' + search
print(product_image_url)

# %%
filename = product_image_url.split("/")[-1].split("?")[0]
print(filename)
# Out:
# b450m-pro-m2-max-b450m-pro-m2-max-mini-atx-am4-gaming-msi-original-imafxv6nx9hh2pev.jpeg

# %%
## Importing Necessary Modules
import requests # to get image from the web
import shutil # to save it locally

#Set the file name to save
filename = product_image_url.split("/")[-1].split("?")[0]
print(filename)
# Open the url image, set stream to True, this will return the stream content.
r = requests.get(product_image_url, stream = True)
# Check if the image was retrieved successfully
if r.status_code == 200:
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
    r.raw.decode_content = True
    
    # Open a local file with wb ( write binary ) permission.
 
    if not os.path.exists("product_image"):
        os.makedirs("product_image")
    with open("./product_image/"+filename,'wb') as f:
        shutil.copyfileobj(r.raw, f)
        
    print('Image sucessfully Downloaded: ',filename)
else:
    print('Image Couldn\'t be retreived')
# Out:
# b450m-pro-m2-max-b450m-pro-m2-max-mini-atx-am4-gaming-msi-original-imafxv6nx9hh2pev.jpeg
# Image sucessfully Downloaded:  b450m-pro-m2-max-b450m-pro-m2-max-mini-atx-am4-gaming-msi-original-imafxv6nx9hh2pev.jpeg
