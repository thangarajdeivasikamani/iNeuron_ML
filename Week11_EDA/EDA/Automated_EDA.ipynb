# %% [markdown]
# ## 1. D-Tale

# %%
#!pip install dtale

# %%
#https://www.kdnuggets.com/2020/08/bring-pandas-dataframes-life-d-tale.html
import dtale

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Sushil-PC:40001/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 2.Sweetviz

# %%
#!pip install ipywidgets

# %%
#!pip install sweetviz

# %%
# importing sweetviz
import sweetviz as sv#analyzing the dataset
advert_report = sv.analyze(df)#display the report
advert_report.show_html('Advertising.html')
# report will saved in the root folder
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Advertising.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## 3.pandas-profiling

# %%
#!pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# %%
profile.to_file("df_report.html")
# report will stored in root folder
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.to_csv('tips.csv')

# %% [markdown]
# ## 4. autoviz

# %%
#!pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
# It will give some basic info & also list of chart.
# User has to understand the graph like scatter plot, distribution ,outlier,how to Transform etc..
df = AV.AutoViz('tips.csv')
# Out:
# Shape of your Data Set: (244, 8)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         This does not include the Target column(s)
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 2.952
#
#  ###################### VISUALIZATION Completed ########################

# %% [markdown]
# ## 6. pandas-visual-analysis

# %%
#!pip install pandas-visual-analysis

# %%
import pandas as pd

from pandas_visual_analysis import VisualAnalysis

import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(df)

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"

df1 = pd.read_csv(url)
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin  name
# 0          70    usa  None
# 1          70    usa  None
# 2          70    usa  None
# 3          70    usa  None
# 4          70    usa  None

# %%
# If you want to specify which columns of the DataFrame are categorical, just pass the categorical_columns option:
# from pandas_visual_analysis import VisualAnalysis
# categorical = ["origin", "model_year", "cylinders"]
# VisualAnalysis(df, categorical_columns=categorical)

# %% [markdown]
# ## 7. lux-api

# %%
#!pip install lux-api

# %%
#https://analyticsindiamag.com/python-guide-to-lux-an-interactive-visual-discovery/
import pandas as pd
import lux 
df = pd.read_csv("tips.csv")
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ## 8. shapash

# %%
# https://shapash.readthedocs.io/en/latest/tutorials/tutorial02-Shapash-overview-in-Jupyter.html
#! pip install shapash

# %%
# shapash library python

# %% [markdown]
# ## 9.DSNE

# %%
#https://analyticsindiamag.com/complete-guide-to-dsne-a-velocity-visualization-tool/

# %% [markdown]
# ## 10.Knowledge Graph Embedding

# %%
#https://analyticsindiamag.com/pykg2vec/

# %% [markdown]
# ## 11. qgrid

# %%
#! pip install qgrid

# %%
#conda install qgrid

# %%
#https://mybinder.org/v2/gh/quantopian/qgrid-notebooks/master?filepath=index.ipynb
#https://notebooks.gesis.org/binder/jupyter/user/tkrabel-qgrid_jupyterlab-ttnoa57j/lab
import numpy as np
import pandas as pd
import qgrid

randn = np.random.randn
df_types = pd.DataFrame({
    'A' : pd.Series(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
               '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09'],index=list(range(9)),dtype='datetime64[ns]'),
    'B' : pd.Series(randn(9),index=list(range(9)),dtype='float32'),
    'C' : pd.Categorical(["washington", "adams", "washington", "madison", "lincoln","jefferson", "hamilton", "roosevelt", "kennedy"]),
    'D' : ["foo", "bar", "buzz", "bippity","boppity", "foo", "foo", "bar", "zoo"] })
df_types['E'] = df_types['D'] == 'foo'
qgrid.show_grid(df_types, show_toolbar=True)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
