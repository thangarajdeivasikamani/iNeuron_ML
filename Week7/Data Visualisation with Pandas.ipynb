# %%
# interactive graph
import numpy as np
import pandas as pd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
# Create 1000 random & assign date as index
# Assign column name as value
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.643719
# 2019-06-08 -1.255399
# 2019-06-09 -0.193517
# 2019-06-10 -0.885212
# 2019-06-11  0.487255

# %%
print(df.shape)
print(ts.shape)
# Out:
# (1000, 1)
# (1000,)

# %%
#Series 
ts.head()
# Out:
# 2019-06-07    0.380724
# 2019-06-08   -0.328848
# 2019-06-09   -0.126350
# 2019-06-10    1.800855
# 2019-06-11   -0.522212
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
# Now we need to check whether my series going up or down we will plot series/example stock price
# X-index is data, Y -axis is value
ts.plot()

# %%
# Change the fig size
ts.plot(figsize=(5,5))

# %%
# Another way of ploting
plt.plot(ts)

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.380724
# 2019-06-08    0.051876
# 2019-06-09   -0.074474
# 2019-06-10    1.726381
# 2019-06-11    1.204169
# Freq: D, dtype: float64

# %%
# After applying function( Cumsum,normalize,standradize) and visuvalize the series/changing behaviuor
ts.plot()

# %% [raw]
# # Differnce between power BI & Tabulu  & matplot
# # BI & Tabulu  -  Dashboard reporting tool
# # matplot - raw data visuvalize, data anaysis
# # More advanced/anotation use - seaborn,plotly, boksh

# %%
df.plot()

# %%
# Calculate the cumulartive sum
# Add previuos + current
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.643719
# 2019-06-08 -1.899117
# 2019-06-09 -2.092634
# 2019-06-10 -2.977846
# 2019-06-11 -2.490591

# %%
# Similar way assign some function do the ploting & Observe the behaviours
df.plot()

# %% [markdown]
# ###  Load  the default open data

# %%
path = r'C:\MachineLearning\iNeuron_ML\Week7\iris.csv'
iris = pd.read_csv(path)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Plot the flower dataset 
# Qustion: lenght of range of particular flower 
# Which one has more change - Petal_length
# No of data 
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
# Default is line plot
ts.plot(kind = 'bar')

# %%
# Drop the cat feature
df = iris.drop(['species'], axis = 1)

# %%
# Extract the single row & plot
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
path = r'C:\MachineLearning\iNeuron_ML\Week7\titanic.xls'
titanic = pd.read_excel(path)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  1.331603  0.541308 -1.168424 -0.249637
# 1  0.286267  1.627583 -0.055349  0.893015
# 2 -0.193142  0.140321  1.281598  1.667808
# 3 -2.169994 -1.774161 -0.766357 -0.009724
# 4  0.201812  0.206746 -1.198189 -0.807337
# 5 -0.983740  0.754345  2.276966  0.040537
# 6  1.925241  0.219882 -0.910125 -1.922372
# 7  2.121511 -0.958171 -0.909983 -1.285471
# 8 -0.070389 -1.777518  1.247577  0.166651
# 9  0.607129 -0.760270  0.781691  0.557249

# %%
df.plot.bar()

# %%
# index is 0 to 9
# index 0 value of a,b,c,d  - Here b is positive
df.plot(kind = 'bar')

# %%
# Vertical
df.plot.barh()

# %% [markdown]
# ### histogram

# %%
# Frequncy of length
iris['petal_length'].plot.hist()

# %%
iris.plot.hist()

# %%
# Here overlapped
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
# with bin value & stacked removed
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
# Find the differnce b/w data
# First data is nan
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
# 5      0.3
# 6     -0.5
# 7      0.0
# 8     -0.5
# 9      0.2
# 10     0.6
# 11    -0.3
# 12    -0.4
# 13     0.0
# 14     1.0
# 15     0.4
# 16    -0.5
# 17    -0.4
# 18     0.3
# 19     0.0
# 20    -0.4
# 21     0.3
# 22    -0.1
# 23    -0.3
# 24     0.1
# 25    -0.4
# 26     0.4
# 27     0.1
# 28    -0.1
# 29    -0.2
#       ...
# 120    1.0
# 121   -0.4
# 122    0.0
# 123   -0.1
# 124    0.6
# 125   -0.1
# 126   -0.4
# 127    0.2
# 128   -0.2
# 129    0.2
# 130   -0.2
# 131    1.0
# 132   -1.0
# 133    0.0
# 134   -0.2
# 135    0.4
# 136    0.4
# 137   -0.3
# 138   -0.1
# 139    0.1
# 140    0.0
# 141    0.0
# 142   -0.4
# 143    0.5
# 144    0.1
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %% [raw]
# Question:
# 1. Plot a graph for fare price variation
# 2. Try to show survied in histogram.

# %%
titanic['fare'].plot()

# %%
# Survied around 500, not survied 800
titanic['survived'].plot(kind = 'hist')

# %%
# Cal culate the differcence between each value
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
# Plot entire dataset difference one shot
# Color we can give letter or code 
# Aplpha  is intensity
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000150C8390>,
# ...
#       dtype=object)

# %%
# Change the color & plot
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %% [markdown]
# ### Scatter

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
# Scatter plot with label
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width',  color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Plot the scatter between sepal_length & petal_length
# we need with repect third data
# sepal_length & petal_length first values are 5.1 & 1.4 - This x axis and y axis co-ordinate 
# Now sepal_width is 3.5 - Check the color light black(side slide bar) - so the dot will get that color
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
# Scatter plot with size of dot
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %% [markdown]
# ### hexbin

# %%
# Insead of scatter we will plot hexbin, we need to give grid size
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %% [markdown]
# ### Pie

# %%
# Single row
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
# Take three rows
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
# multiple pie chart
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016996898>,
# ...
#       dtype=object)

# %%
# with % percentage value
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 10, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016833D68>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
# Create the series & Check the % 
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie(fontsize = 10, autopct = '%.2f')

# %% [markdown]
# ## scatter matrix

# %%
# we can see the relation b/w each & every column
# Diagonal normal distribution
# if it is not normalized - we need to normalize.

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %% [markdown]
# ### KDE

# %% [raw]
# # will help whether my column is normalized or not
# # Kernal density estimation

# %%
ts.plot.kde()

# %%
df['sepal_length'].plot(kind='kde')

# %% [markdown]
# ### andrews_curves

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
## change the plot style

# %%
# Dotted line
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
ts.plot(style = 'r*', label = 'Series', legend = True)

# %%
# plot entire data frame using log
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016B9ECC0>,
# ...
#       dtype=object)

# %%
# sub plot & layout
# Sharex - set axis same vaLue 
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-73-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
