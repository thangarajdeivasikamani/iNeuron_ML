# %% [markdown]
# ## MatplotLib Tutorial
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
# interactive graph
import matplotlib.pyplot as plt


#%matplotlib notebook 
# %matplotlib inline

# %%
import numpy as np

# %% [markdown]
# # Line

# %%
# index default in x- axis
plt.plot([1,2,3,4,5,6])

# %%
# x-axis and y -axis
plt.plot([1,2,3,4,5],[5,6,7,8,9])

# %%
plt.plot([1,2,3,4,5],[5,6,7,8,9],linewidth =6, color='r',ls ='dashed')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %% [markdown]
# # Bar

# %%
# comparsion of two series

# %%
x =[2,3,4,5,6,7]
y = [10,15,20,25,19,17]
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
x =[2,3,4,5,6,7]
y = [10,15,20,25,19,17]
plt.bar(x,y)
plt.title('Out bar chart')
plt.xlabel('X label text')
plt.ylabel('Y label text')
# Out:
# Text(0, 0.5, 'Y label text')

# %%
# Multiple bar chart-overlapped
x =[2,3,4,5,6,7]
y = [10,15,20,25,19,17]
x2 = [2,3,4,5,6,7]
y2 = [15,25,19,16,18,20]
plt.bar(x,y)
plt.bar(x2,y2)
plt.title('Out bar chart')
plt.xlabel('X label text')
plt.ylabel('Y label text')
# Out:
# Text(0, 0.5, 'Y label text')

# %%
# How to overcome giving alpha
# Multiple bar chart-overlapped
x =[2,3,4,5,6,7]
y = [10,15,20,25,19,17]
x2 = [2,3,4,5,6,7]
y2 = [15,25,19,16,18,20]
plt.bar(x,y,alpha =.5,label = 'First')
plt.bar(x2,y2,alpha = 0.5,label ='second')
plt.title('Out bar chart')
plt.xlabel('X label text')
plt.ylabel('Y label text')
plt.legend()

# %%
# Another way width
plt.figure(figsize=(10,10))
plt.bar(x,y,width =.9,label = 'First')
plt.bar(x2,y2,width = 0.7,label ='second')
plt.title('Out bar chart')
plt.xlabel('X label text')
plt.ylabel('Y label text')
plt.legend()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %% [markdown]
# # Historgam

# %%
# Help to indetify the distribution
# Also frequency count

# %%
height = np.arange(150,200,2)
plt.hist(height)
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 3., 2., 3.]),
#  array([150. , 154.8, 159.6, 164.4, 169.2, 174. , 178.8, 183.6, 188.4,
#         193.2, 198. ]),
#  <a list of 10 Patch objects>)

# %%
# using row width we segegate
plt.hist(height,rwidth = 0.9)
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 3., 2., 3.]),
#  array([150. , 154.8, 159.6, 164.4, 169.2, 174. , 178.8, 183.6, 188.4,
#         193.2, 198. ]),
#  <a list of 10 Patch objects>)

# %%
bin = [155,165,175,185,195,200]
plt.hist(height,rwidth = 0.9,bins = bin)
# Out:
# (array([5., 5., 5., 5., 2.]),
#  array([155, 165, 175, 185, 195, 200]),
#  <a list of 5 Patch objects>)

# %%
# Here value will take as bin
height = np.arange(150,200,2)
value = np.random.randn(20)
plt.hist([height,value],rwidth = 0.9)
# Out:
# ([array([ 0.,  0.,  0.,  0.,  0.,  0.,  0.,  5., 10., 10.]),
#   array([20.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.])],
#  array([ -1.67710667,  18.290604  ,  38.25831467,  58.22602533,
#          78.193736  ,  98.16144667, 118.12915733, 138.096868  ,
#         158.06457867, 178.03228933, 198.        ]),
#  <a list of 2 Lists of Patches objects>)

# %%
height_m = np.arange(150,200,2)
height_f = np.arange(140,180,2)
plt.hist([height_m,height_f],rwidth = 0.9,label = ['male','female']) 
plt.legend()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %%
# Random distribution with horizontal
# Refer lib for more details & other parameter
plt.hist(np.random.randn(1000),rwidth =0.9,orientation='horizontal')
# Out:
# (array([  9.,  29.,  57., 143., 208., 219., 165., 113.,  43.,  14.]),
#  array([-3.11938169, -2.5261967 , -1.93301171, -1.33982672, -0.74664173,
#         -0.15345673,  0.43972826,  1.03291325,  1.62609824,  2.21928323,
#          2.81246823]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # scatter

# %%
# Show the relationship
# rain affect the sales price

# %%
x =[1,3,5,7,9,11,13]
y =[25,35,21,67,63,55,30]
plt.scatter(x,y)

# %%
x =[1,3,5,7,9,11,13]
y =[25,35,21,67,63,55,30]
plt.scatter(x,y,marker = '*')

# %%
x1 =[1,3,5,7,9,11,13]
y1 =[25,35,21,67,63,55,30]
x2 = [1,3,5,7,9,11,13]
y2 = [30,24,65,45,39,55,21]
plt.scatter([x1,x2],[y1,y2],marker = '+')

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
## Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
# Import the data
# 0 indicate first sheet
import pandas as pd
path = r'C:\MachineLearning\iNeuron_ML\Week7\Sample - Superstore Sales (Excel).xls'
orders =pd.read_excel(path,0)
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
# High sales,high discount,few outlier
plt.scatter(orders.Sales,orders.Discount)

# %%
# based on profit or Unit Price my size
plt.scatter(orders.Sales,orders.Discount,s = orders['Unit Price'])

# %%
fig,ax = plt.subplots()

ax.plot([0],[0], marker="o",  markersize=10)
ax.plot([0.07,0.93],[0,0],    linewidth=10)
ax.scatter([1],[0],           s=100)

ax.plot([0],[1], marker="o",  markersize=22)
ax.plot([0.14,0.86],[1,1],    linewidth=22)
ax.scatter([1],[1],           s=22**2)

plt.show()

# %% [markdown]
# ## Area plot

# %% [raw]
# Example whether my production for each shift increase or decrease

# %%
week = [1,2,3,4,5]
shift1 = [40,35,26,23,20]
shift2 = [40,32,40,45,50]
shift3= [40,35,45,42,40]
plt.stackplot(week,shift1,shift2,shift3,labels=['shift1','shift2','shift3'])
plt.legend()

# %% [markdown]
# ## Practical example

# %%
orders['Ship Mode'].value_counts()
# Out:
# Regular Air       6270
# Delivery Truck    1146
# Express Air        983
# Name: Ship Mode, dtype: int64

# %%
orders_ra = orders[orders['Ship Mode']== 'Regular Air'].Sales
orders_dt = orders[orders['Ship Mode']== 'Delivery Truck'].Sales
orders_ea = orders[orders['Ship Mode']== 'Express Air'].Sales

# %%
# If we give the one value, but x -axis is take index
# why x-axis comming as 8000
plt.plot(orders_ea,'r+')

# %%
orders_ea.head()
# Out:
# 8     2781.82
# 21      59.03
# 47      49.59
# 62     130.32
# 63     312.36
# Name: Sales, dtype: float64

# %%
plt.plot(orders_ea,'r+',alpha = 0.3)
plt.plot(orders_ra,'go',alpha  = 0.3)
plt.plot(orders_dt,'b^',alpha  = 0.3)

# %%
# how to resolve the above issue - like you goes 8000
# issue here is inde
print(orders_ea.shape)
print(orders_ra.shape)
print(orders_dt.shape)
# Out:
# (983,)
# (6270,)
# (1146,)

# %%
orders_ea_index = np.arange(0,983,1)
orders_ea.index = orders_ea_index
# Now we can see index only 983
plt.plot(orders_ea,'r+',alpha = 0.3)

# %%
orders_ra_index = np.arange(0,6270,1)
orders_ra.index = orders_ra_index

# %%
orders_dt_index = np.arange(0,1146,1)
orders_dt.index = orders_dt_index

# %%
plt.plot(orders_ea,'r+',alpha = 0.3)
plt.plot(orders_ra,'go',alpha  = 0.3)
plt.plot(orders_dt,'b^',alpha  = 0.3)

# %% [markdown]
# ## Scatter matrix

# %% [raw]
# How the varaible are cp-related

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
# Draw the diagonal plot as distribution(Kernal density estimation)
import pandas as pd
pd.plotting.scatter_matrix(orders,figsize =(20,20),diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001544DDD8>,
# ...
#       dtype=object)

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=False,patch_artist=False);

# %%
#data

# %%
# Show the outlier
plt.boxplot(orders.Discount)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19c1c2e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19c20048>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19c1c048>],
#  'medians': [<matplotlib.lines.Line2D at 0x19c20d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19c233c8>],
#  'means': []}

# %%
plt.boxplot(orders.Profit)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19c69898>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19c69f28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19c69748>],
#  'medians': [<matplotlib.lines.Line2D at 0x19c775f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19c77940>],
#  'means': []}

# %%
plt.boxplot(orders['Order Quantity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ddda58>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19de8128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ddd908>],
#  'medians': [<matplotlib.lines.Line2D at 0x19de87b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19de8b00>],
#  'means': []}

# %%
# Shoe the mean line
plt.boxplot(orders['Order Quantity'],showmeans = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22422b70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22425240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22422a20>],
#  'medians': [<matplotlib.lines.Line2D at 0x224258d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22425f28>],
#  'means': [<matplotlib.lines.Line2D at 0x22425c18>]}

# %%
# Change the style
plt.boxplot(orders.Discount,sym = 'g+')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x224725f8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22472c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x224724a8>],
#  'medians': [<matplotlib.lines.Line2D at 0x22477358>],
#  'fliers': [<matplotlib.lines.Line2D at 0x224776a0>],
#  'means': []}

# %%
# Confence interval
plt.boxplot(orders.Discount,1,sym = 'g+')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2249aba8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x224a1278>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2249aa58>],
#  'medians': [<matplotlib.lines.Line2D at 0x224a1908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x224a1c50>],
#  'means': []}

# %%
# Remove the unncessary line - using semi colon
# Confence interval
plt.boxplot(orders.Discount,1,sym = 'g+');

# %%
# remove the outlier sym as None
plt.boxplot(orders.Discount,1,sym = '')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x224f86a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x224f8d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x224f8550>],
#  'medians': [<matplotlib.lines.Line2D at 0x224ff400>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# # Interactive

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook 
x = [2,5,7,9,12]
y = [5,8,10,15,17]
plt.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Pie Chart

# %%
# Data to plot
# %matplotlib qt  will help separte interactive windows
# %matplotlib qt 
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False)

plt.axis('equal')
plt.show()
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Adjusting axis limits,label names and adding grid

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
# Row ID                  8399 non-null int64
# Order ID                8399 non-null int64
# Order Date              8399 non-null datetime64[ns]
# Order Priority          8399 non-null object
# Order Quantity          8399 non-null int64
# Sales                   8399 non-null float64
# Discount                8399 non-null float64
# Ship Mode               8399 non-null object
# Profit                  8399 non-null float64
# Unit Price              8399 non-null float64
# Shipping Cost           8399 non-null float64
# Customer Name           8399 non-null object
# Province                8399 non-null object
# Region                  8399 non-null object
# Customer Segment        8399 non-null object
# Product Category        8399 non-null object
# Product Sub-Category    8399 non-null object
# Product Name            8399 non-null object
# ...

# %%
# pivot kind of table
orders['Year'] = orders['Order Date'].dt.year

# %%
sales_pivot = pd.pivot_table(orders,values = "Sales",index = ['Year'],columns=['Ship Mode'])
sales_pivot
# Out:
# Ship Mode  Delivery Truck  Express Air  Regular Air
# Year
# 2009          5601.796746  1278.645028  1370.890765
# 2010          5092.764231  1283.833311  1081.759219
# 2011          5706.763645  1000.244126  1146.833239
# 2012          5353.346270  1291.215876  1186.918362

# %%
plt.plot(sales_pivot);

# %%
# above plot axis missing,label mising
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
plt.legend()

# %%
# Move the legend postion
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
#plt.legend(loc = 1)
#plt.legend(loc = 'upper right')
plt.legend(loc = [0.2,0.2]) # cordinate

# %% [markdown]
# ## Save the plot

# %%
plt.savefig('Sales_by_ship_mode.pdf')

# %% [markdown]
# ## customize the font size

# %%
plt.rcParams['font.size'] =12
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
plt.legend()

# %%
plt.rcParams['font.size'] =10
plt.rcParams['font.family'] = 'serif'
plt.style.use('fivethirtyeight')
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
plt.legend()

# %%
# reset to default
plt.rcParams['font.size'] =10
plt.rcParams['font.family'] = 'serif'
plt.style.use('default')
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
plt.legend()

# %%
# various styles
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# Rc params line width across the note book
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.linestyle'] = 'Dashed'
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.labelsize'] = 5
plt.rcParams['font.size'] =10
plt.rcParams['font.family'] = 'serif'
plt.style.use('ggplot')
plt.plot(sales_pivot,label = ['Delivery Truck,Express Air','Regular Air'])
plt.xlim(2009,2012)
plt.ylim(1000,6000)
plt.xlabel('Sales Year')
plt.ylabel('Sales by ship mode')
plt.legend()

# %% [markdown]
# ## Configuarion file across the notebok

# %%
# Configuarion file across the notebok
# Open the specified path file in notebook
# Modify the required values & save
import matplotlib as mpl
mpl.matplotlib_fname()
# Out:
# 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# ## Text annotation

# %%
# Change the co-ordinate value
# Chnage the font size
plt.text(.25,.5,'This is center',fontsize =10)
plt.show()
