# %%
#

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 3.1 Now New Tree model created, Here Training  datas feature are Married,Gender,Current City,Monthly income,
# Target data is Residual1
# Now model will predict new value that is called  Predecition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
